# %%
import re

# Parsing function
def parse_to_list(data):
    iterations = []
    current_iteration = {}

    for line in data.splitlines():
        if line.startswith("== Iteration"):
            if current_iteration:
                iterations.append(current_iteration)  # Save previous iteration
            current_iteration = {}  # Start a new iteration
        elif "Thread id" in line:
            match = re.search(r"\[(\d+)\]", line)
            if match:
                current_iteration['thread_id'] = int(match.group(1))
        elif ":" in line:
            _, key, value = map(str.strip, line.split(":", 2))
            key = key.replace(" ", "_").lower()
            try:
                value = int(value.split()[0])  # Extract numeric value
            except ValueError:
                pass  # Keep as string if not a number
            current_iteration[key] = value

    if current_iteration:  # Add the last iteration
        iterations.append(current_iteration)

    return iterations

# %%
# Input data
with open('list-result.txt') as f:
    data = f.read()

# Parse the data
parsed_list = parse_to_list(data)

# Print the result
import pprint
pprint.pprint(parsed_list)

import pandas as pd

df = pd.DataFrame(parsed_list)
df.to_csv('parsed-result.csv')
# Out:
# [{'execution_time': 43024690,
#   'injected_delay_cycles': 42113948726,
#   'injected_delay_in_usec': 16845579,
#   'latency_calculation_overhead_cycles': 0,
#   'nvm_accesses': 123885281,
#   'stall_cycles': 22918777063,
#   'thread_id': 3141500},
#  {'execution_time': 41831135,
#   'injected_delay_cycles': 46859877404,
#   'injected_delay_in_usec': 18743950,
#   'latency_calculation_overhead_cycles': 0,
#   'nvm_accesses': 137843921,
#   'stall_cycles': 25501125501,
#   'thread_id': 3141588},
#  {'execution_time': 42217654,
#   'injected_delay_cycles': 45013714221,
#   'injected_delay_in_usec': 18012690,
#   'latency_calculation_overhead_cycles': 0,
#   'nvm_accesses': 133133479,
#   'stall_cycles': 24496560169,
#   'thread_id': 3141674},
#  {'execution_time': 42459316,
#   'injected_delay_cycles': 44412388657,
#   'injected_delay_in_usec': 17772064,
#   'latency_calculation_overhead_cycles': 0,
#   'nvm_accesses': 131354592,
#   'stall_cycles': 24169245081,
#   'thread_id': 3141760},
#  {'execution_time': 42253179,
#   'injected_delay_cycles': 45022717214,
#   'injected_delay_in_usec': 18009086,
#   'latency_calculation_overhead_cycles': 0,
#   'nvm_accesses': 132442443,
#   'stall_cycles': 24501852013,
#   'thread_id': 3141846},
#  {'execution_time': 42243182,
#   'injected_delay_cycles': 45202171510,
#   'injected_delay_in_usec': 18109844,
#   'latency_calculation_overhead_cycles': 0,
#   'nvm_accesses': 133691207,
#   'stall_cycles': 24599182156,
#   'thread_id': 3141935},
#  {'execution_time': 41306559,
#   'injected_delay_cycles': 49361115631,
#   'injected_delay_in_usec': 19744446,
#   'latency_calculation_overhead_cycles': 0,
#   'nvm_accesses': 145200608,
#   'stall_cycles': 26862112598,
#   'thread_id': 3142021},
#  {'execution_time': 41428283,
#   'injected_delay_cycles': 48697218700,
#   'injected_delay_in_usec': 19478887,
#   'latency_calculation_overhead_cycles': 0,
#   'nvm_accesses': 143248222,
#   'stall_cycles': 26500921150,
#   'thread_id': 3142107},
#  {'execution_time': 41603310,
#   'injected_delay_cycles': 48868444625,
#   'injected_delay_in_usec': 19547377,
#   'latency_calculation_overhead_cycles': 0,
#   'nvm_accesses': 143752563,
#   'stall_cycles': 26594224196,
#   'thread_id': 3142195},
#  {'execution_time': 42396581,
#   'injected_delay_cycles': 44509750667,
#   'injected_delay_in_usec': 17803900,
#   'latency_calculation_overhead_cycles': 0,
#   'nvm_accesses': 130933321,
#   'stall_cycles': 24222664426,
#   'thread_id': 3142281}]

# %%
# Input data
with open('list-result-4kb.txt') as f:
    data = f.read()

# Parse the data
parsed_list = parse_to_list(data)

import pandas as pd

df = pd.DataFrame(parsed_list)
df.to_csv('parsed-result-4kb.csv')
