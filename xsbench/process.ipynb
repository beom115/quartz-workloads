# %%
import pandas as pd

# %%
df = pd.read_csv('parsed-result.csv', index_col=0)
df
# Out:
#    thread_id  execution_time  stall_cycles  nvm_accesses  \
# 0    3141500        43024690   22918777063     123885281
# 1    3141588        41831135   25501125501     137843921
# 2    3141674        42217654   24496560169     133133479
# 3    3141760        42459316   24169245081     131354592
# 4    3141846        42253179   24501852013     132442443
# 5    3141935        42243182   24599182156     133691207
# 6    3142021        41306559   26862112598     145200608
# 7    3142107        41428283   26500921150     143248222
# 8    3142195        41603310   26594224196     143752563
# 9    3142281        42396581   24222664426     130933321
#
#    latency_calculation_overhead_cycles  injected_delay_cycles  \
# 0                                    0            42113948726
# 1                                    0            46859877404
# 2                                    0            45013714221
# 3                                    0            44412388657
# 4                                    0            45022717214
# 5                                    0            45202171510
# 6                                    0            49361115631
# 7                                    0            48697218700
# 8                                    0            48868444625
# 9                                    0            44509750667
#
#    injected_delay_in_usec
# 0                16845579
# 1                18743950
# 2                18012690
# 3                17772064
# 4                18009086
# 5                18109844
# 6                19744446
# 7                19478887
# 8                19547377
# 9                17803900

# %%
df = pd.read_csv('parsed-result.csv', index_col=0)

# 각 컬럼별 평균 및 NSD 계산
results = []
for column in df.columns:
    mean_value = df[column].mean()
    std_dev = df[column].std()
    nsd_percent = (std_dev / mean_value) * 100
    results.append({'Column': column, 'Mean': mean_value, 'NSD (%)': nsd_percent})

# 결과를 DataFrame으로 정리
results_df = pd.DataFrame(results)
print(results_df)
# Out:
#                                 Column          Mean   NSD (%)
# 0                            thread_id  3.141891e+06  0.008360
# 1                       execution_time  4.207639e+07  1.258615
# 2                         stall_cycles  2.503667e+10  5.119780
# 3                         nvm_accesses  1.355486e+08  5.032980
# 4  latency_calculation_overhead_cycles  0.000000e+00       NaN
# 5                injected_delay_cycles  4.600613e+10  5.120522
# 6               injected_delay_in_usec  1.840678e+07  5.108844
# /var/folders/vr/nktrh3g56ts4vqrpgnhr3p400000gn/T/ipykernel_49129/1492965760.py:8: RuntimeWarning: invalid value encountered in double_scalars
#   nsd_percent = (std_dev / mean_value) * 100

# %%
df = pd.read_csv('parsed-result-4kb.csv', index_col=0)

# 각 컬럼별 평균 및 NSD 계산
results = []
for column in df.columns:
    mean_value = df[column].mean()
    std_dev = df[column].std()
    nsd_percent = (std_dev / mean_value) * 100
    results.append({'Column': column, 'Mean': mean_value, 'NSD (%)': nsd_percent})

# 결과를 DataFrame으로 정리
results_df = pd.DataFrame(results)
print(results_df)
# Out:
#                                 Column          Mean   NSD (%)
# 0                            thread_id  3.141013e+06  0.008373
# 1                       execution_time  5.218222e+07  0.892642
# 2                         stall_cycles  3.255963e+10  1.502254
# 3                         nvm_accesses  1.717815e+08  8.356429
# 4  latency_calculation_overhead_cycles  0.000000e+00       NaN
# 5                injected_delay_cycles  5.983219e+10  1.502681
# 6               injected_delay_in_usec  2.329508e+07  8.341946
# /var/folders/vr/nktrh3g56ts4vqrpgnhr3p400000gn/T/ipykernel_49129/3909240025.py:8: RuntimeWarning: invalid value encountered in double_scalars
#   nsd_percent = (std_dev / mean_value) * 100
