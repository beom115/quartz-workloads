# %%
import re

# Parsing function
def parse_to_list(data):
    iterations = []
    current_iteration = {}

    for line in data.splitlines():
        if line.startswith("== Iteration"):
            if current_iteration:
                iterations.append(current_iteration)  # Save previous iteration
            current_iteration = {}  # Start a new iteration
        elif "Thread id" in line:
            match = re.search(r"\[(\d+)\]", line)
            if match:
                current_iteration['thread_id'] = int(match.group(1))
        elif ":" in line:
            _, key, value = map(str.strip, line.split(":", 2))
            key = key.replace(" ", "_").lower()
            try:
                value = int(value.split()[0])  # Extract numeric value
            except ValueError:
                pass  # Keep as string if not a number
            current_iteration[key] = value

    if current_iteration:  # Add the last iteration
        iterations.append(current_iteration)

    return iterations

# %%
# Input data
with open('list-result.txt') as f:
    data = f.read()

# Parse the data
parsed_list = parse_to_list(data)

# Print the result
import pprint
pprint.pprint(parsed_list)

import pandas as pd

df = pd.DataFrame(parsed_list)
df.to_csv('parsed-result.csv')
# Out:
# [{'execution_time': 698726881,
#   'injected_delay_cycles': 834894760718,
#   'injected_delay_in_usec': 333957904,
#   'latency_calculation_overhead_cycles': 0,
#   'nvm_accesses': 2455813976,
#   'stall_cycles': 454325585578,
#   'thread_id': 3155089},
#  {'execution_time': 723373128,
#   'injected_delay_cycles': 873608099158,
#   'injected_delay_in_usec': 256943558,
#   'latency_calculation_overhead_cycles': 218266,
#   'nvm_accesses': 1893984306,
#   'stall_cycles': 475390060979,
#   'thread_id': 3155182},
#  {'execution_time': 817888188,
#   'injected_delay_cycles': 934156071070,
#   'injected_delay_in_usec': 373662428,
#   'latency_calculation_overhead_cycles': 45821,
#   'nvm_accesses': 2747839502,
#   'stall_cycles': 508350307946,
#   'thread_id': 3155308},
#  {'execution_time': 799119164,
#   'injected_delay_cycles': 994122875697,
#   'injected_delay_in_usec': 397649150,
#   'latency_calculation_overhead_cycles': 25259,
#   'nvm_accesses': 2924154789,
#   'stall_cycles': 540968636016,
#   'thread_id': 3155408},
#  {'execution_time': 790222227,
#   'injected_delay_cycles': 910610210281,
#   'injected_delay_in_usec': 364244084,
#   'latency_calculation_overhead_cycles': 59821,
#   'nvm_accesses': 2678589255,
#   'stall_cycles': 495539012273,
#   'thread_id': 3155535},
#  {'execution_time': 814926848,
#   'injected_delay_cycles': 1039576682144,
#   'injected_delay_in_usec': 415830672,
#   'latency_calculation_overhead_cycles': 0,
#   'nvm_accesses': 3057818477,
#   'stall_cycles': 565696418298,
#   'thread_id': 3155631},
#  {'execution_time': 787989051,
#   'injected_delay_cycles': 960374539769,
#   'injected_delay_in_usec': 384149815,
#   'latency_calculation_overhead_cycles': 116183,
#   'nvm_accesses': 2824893460,
#   'stall_cycles': 522605290102,
#   'thread_id': 3155722},
#  {'execution_time': 748714366,
#   'injected_delay_cycles': 926750137734,
#   'injected_delay_in_usec': 370700055,
#   'latency_calculation_overhead_cycles': 0,
#   'nvm_accesses': 2725983148,
#   'stall_cycles': 504306882462,
#   'thread_id': 3155855},
#  {'execution_time': 714658917,
#   'injected_delay_cycles': 868672087261,
#   'injected_delay_in_usec': 255491790,
#   'latency_calculation_overhead_cycles': 0,
#   'nvm_accesses': 1883283396,
#   'stall_cycles': 472704132614,
#   'thread_id': 3155947},
#  {'execution_time': 739919195,
#   'injected_delay_cycles': 910152990627,
#   'injected_delay_in_usec': 364206879,
#   'latency_calculation_overhead_cycles': 0,
#   'nvm_accesses': 2691718369,
#   'stall_cycles': 495276179928,
#   'thread_id': 3156076}]

# %%
# Input data
with open('list-result-4kb.txt') as f:
    data = f.read()

# Parse the data
parsed_list = parse_to_list(data)

import pandas as pd

df = pd.DataFrame(parsed_list)
df.to_csv('parsed-result-4kb.csv')
